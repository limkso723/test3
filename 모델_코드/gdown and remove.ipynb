# %%
pip install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !gdown 1L9v0NclM6OX5jozfvQ_uQ_lrciDJEbG6
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1L9v0NclM6OX5jozfvQ_uQ_lrciDJEbG6
# To: /content/saved_model_epoch_1.pt
# 100% 473M/473M [00:01<00:00, 242MB/s]

# %%
import os

file_path = "/content/saved_model_epoch_1.pt"

if os.path.exists(file_path):
    os.remove(file_path)
